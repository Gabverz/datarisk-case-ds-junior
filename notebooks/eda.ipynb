# %% [markdown]
# ### Projeto Datarisk Case - Data Science

# %% [markdown]
# #### Análise Exploratória de Dados

# %% [markdown]
# Neste notebook vamos explorar as 4 bases fornecidas (cadastral, info, pagamentos_desenvolvimento e pagamentos_teste) pra entender:
#
# - Estrutura e qualidade dos dados (nulos, tipos, duplicatas)
# - Relação entre as tabelas via ID_CLIENTE e SAFRA_REF
# - Construção da variável target (atraso >= 5 dias)
# - Padrões de comportamento de pagamento ao longo do tempo
#
# O objetivo final é gerar uma base de modelagem consolidada, pronta pra treinar o modelo preditivo de inadimplência.

# %%
import pandas as pd

# %%
# Carregando as 4 bases fornecidas para o case
cadastral = pd.read_csv('../data/base_cadastral.csv')
info = pd.read_csv('../data/base_info.csv')
pagamentos_dev = pd.read_csv('../data/base_pagamentos_desenvolvimento.csv')
pagamentos_teste = pd.read_csv('../data/base_pagamentos_teste.csv')

# %%
# Lendo primeiras impressões sobre os dados
cadastral.head()
# Out:
#   ID_CLIENTE;DATA_CADASTRO;DDD;FLAG_PF;SEGMENTO_INDUSTRIAL;DOMINIO_EMAIL;PORTE;CEP_2_DIG
# 0  1661240395903230676;2013-08-22;99;;Serviços;YA...
# 1  8274986328479596038;2017-01-25;31;;Comércio;YA...
# 2  345447888460137901;2000-08-15;75;;Serviços;HOT...
# 3  1003144834589372198;2017-08-06;49;;Serviços;OU...
# 4  324916756972236008;2011-02-14;88;;Serviços;GMA...
